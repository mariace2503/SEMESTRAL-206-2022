# %% [markdown]
# <a href="https://colab.research.google.com/github/mariace2503/SEMESTRAL-206-2022/blob/main/SEMESTRAL_PROBLEMA_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
Z=1
a=1
x=np.arange(0,12)
y=(1/np.sqrt(2))*(Z/a**3/2)*(1-Z*x/2*a)*np.exp(-Z*x/2*a)
plt.plot(x,y,color="purple")
plt.title("RADICAL DEL HIDRÓGENO")
plt.grid()
plt.show()
